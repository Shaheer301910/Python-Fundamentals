# %% [markdown]
# # Variables

# %% [markdown]
# In a programming language a variable is a storage location with a name. They are containers for storing data values. A variable is created the first time it is assigned a value. Assigning a valueto an existingvariable replacesthe previously stored value.

# %%
a = 5
b = 'python'
print(a)
print(b)
# Out:
# 5
# python

# %% [markdown]
# __In python variables do not need to be declared with any particular type, and  we can even change the type after they have been set.__

# %% [markdown]
# If we want to specify the data type of a variable, we can do that with `casting`.

# %%
a = int(3)
b = str(3)

print(type(a))
print(type(b))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# Variable names are case-sensitive.

# %%
a = 3
A = 1

print(a)
print(A)
# Out:
# 3
# 1

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Allowed variable names in Python

mylanguage = 'Python'
my_language = 'Python'
_my_language = 'Python'
MYLANGUAGE = 'Python'
mylanguage1 = 'Python'

# %%
# Not allowed variable names in Python

1mylanguage = 'Python'
# Out:
#   File "<ipython-input-10-4f0b4f09ab62>", line 3
#     1mylanguage = 'Python'
#      ^
# SyntaxError: invalid syntax

# %%
# Not allowed variable names in Python
my-language = 'Python'
# Out:
#   File "<ipython-input-11-03b35a053fa6>", line 3
#     my-language = 'Python'
#     ^
# SyntaxError: cannot assign to operator

# %%
# Not allowed variable names in Python
my language = 'Python'
# Out:
#   File "<ipython-input-12-437b2c138152>", line 2
#     my language = 'Python'
#        ^
# SyntaxError: invalid syntax

# %% [markdown]
# Python allows you to assign values to multiple variables in one line:

# %%
a, b, c = 'red', 'yellow', 'blue'

print(a)
print(b)
print(c)
# Out:
# red
# yellow
# blue

# %% [markdown]
# Use constants forvalues that shouldremain unchangedthroughout your program. It is common practice to specify a
# constant variable with the use of all capital letters for its name.

# %%
TOTAL_HEIGHT = 20    # constant

# %% [markdown]
# In any programming, data type is an important concept. Variables are used to store data of different types, and different types can do different things. Python has the following built-in data types:
#
# - __Text Type__:	`str`
# - __Numeric Types__:	`int, float, complex`
# - __Sequence Types__:	`list, tuple, range`
# - __Mapping Type__:	`dictionary`
# - __Set Types__:	`set, frozenset`
# - __Boolean Type__: `bool`
# - __Binary Types__:	`bytes, bytearray, memoryview`

# %% [markdown]
# __`type()`__ function can be used to get the data type of any object.

# %%
a = 10
print(type(a))
# Out:
# <class 'int'>

# %% [markdown]
# # Important points to remember

# %% [markdown]
# - A variable is a storage location with a name.
# - An assignment statement stores a value in a variable.
# - A variable is created the first time it is assigned a value.
# - Assigning a value to an existing variable replaces the previously stored value.
# - The assignment operator = does not denote mathematical equality.
# - The data type of a value specifies how the value is stored in the computer and what operations can be performed on the value.
# - Integers are whole numbers without a fractional part.
# - Floating-point numbers contain a fractional part.
# - By convention, variable names should start with a lowercase letter.
# - Use constants for values that should remain unchanged throughout your program.
# - Use comments to add explanations for humans who read your code. The interpreter ignores comments.
